# %%
import pandas as pd

# %%
df = pd.read_csv('mpg.csv')
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.manufacturer == 'audi'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: manufacturer, Length: 234, dtype: bool

# %%
df[df.manufacturer == 'audi']
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8          audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# ...

# %%
df.query('manufacturer == "audi"')
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8          audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# ...

# %%
df.query('manufacturer != "audi"')
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 20     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 21     chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 22     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# ..           ...                 ...    ...   ...  ...         ...  ..  ...
# 229   volkswagen              passat    2.0  2008    4    auto(s6)   f   19
# 230   volkswagen              passat    2.0  2008    4  manual(m6)   f   21
# 231   volkswagen              passat    2.8  1999    6    auto(l5)   f   16
# 232   volkswagen              passat    2.8  1999    6  manual(m5)   f   18
# 233   volkswagen              passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 18    20  r      suv
# ...

# %%
df.query('cty > 25')
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 99         honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 104        honda       civic    1.8  2008    4  manual(m5)   f   26   34  r
# 195       toyota     corolla    1.8  1999    4  manual(m5)   f   26   35  r
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 197       toyota     corolla    1.8  2008    4    auto(l4)   f   26   35  r
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 99   subcompact
# 104  subcompact
# 195     compact
# 196     compact
# 197     compact
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
df.query('20 <= cty <= 25')
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi            a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi            a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi            a4    2.0  2008    4    auto(av)   f   21   30  p
# 9           audi    a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 33     chevrolet        malibu    2.4  2008    4    auto(l4)   f   22   30  r
# 100        honda         civic    1.6  1999    4    auto(l4)   f   24   32  r
# 101        honda         civic    1.6  1999    4  manual(m5)   f   25   32  r
# 102        honda         civic    1.6  1999    4  manual(m5)   f   23   29  p
# 103        honda         civic    1.6  1999    4    auto(l4)   f   24   32  r
# 105        honda         civic    1.8  2008    4    auto(l5)   f   25   36  r
# 106        honda         civic    1.8  2008    4    auto(l5)   f   24   36  c
# ...

# %%
df.query('manufacturer == "toyota" and cty>10')
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 173       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 175       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 177       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 178       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 179       toyota                   camry    2.2  1999    4  manual(m5)   f
# 180       toyota                   camry    2.2  1999    4    auto(l4)   f
# 181       toyota                   camry    2.4  2008    4  manual(m5)   f
# 182       toyota                   camry    2.4  2008    4    auto(l5)   f
# 183       toyota                   camry    3.0  1999    6    auto(l4)   f
# ...

# %%
df.query('manufacturer in ["toyoya","honda","nissan"]')
# Out:
#     manufacturer           model  displ  year  cyl       trans drv  cty  hwy  \
# 99         honda           civic    1.6  1999    4  manual(m5)   f   28   33
# 100        honda           civic    1.6  1999    4    auto(l4)   f   24   32
# 101        honda           civic    1.6  1999    4  manual(m5)   f   25   32
# 102        honda           civic    1.6  1999    4  manual(m5)   f   23   29
# 103        honda           civic    1.6  1999    4    auto(l4)   f   24   32
# 104        honda           civic    1.8  2008    4  manual(m5)   f   26   34
# 105        honda           civic    1.8  2008    4    auto(l5)   f   25   36
# 106        honda           civic    1.8  2008    4    auto(l5)   f   24   36
# 107        honda           civic    2.0  2008    4  manual(m6)   f   21   29
# 141       nissan          altima    2.4  1999    4  manual(m5)   f   21   29
# 142       nissan          altima    2.4  1999    4    auto(l4)   f   19   27
# ...

# %%
df.query('manufacturer not in ["toyota","honda","nissan"]')
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.query('manufacturer not in ["toyota","honda","nissan"] and drv in ["4","f"]')
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.manufacturer.str.startswith('f')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: manufacturer, Length: 234, dtype: bool

# %%
df[df.manufacturer.str.startswith('f')]
# Out:
#    manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 74         ford   expedition 2wd    4.6  1999    8    auto(l4)   r   11   17
# 75         ford   expedition 2wd    5.4  1999    8    auto(l4)   r   11   17
# 76         ford   expedition 2wd    5.4  2008    8    auto(l6)   r   12   18
# 77         ford     explorer 4wd    4.0  1999    6    auto(l5)   4   14   17
# 78         ford     explorer 4wd    4.0  1999    6  manual(m5)   4   15   19
# 79         ford     explorer 4wd    4.0  1999    6    auto(l5)   4   14   17
# 80         ford     explorer 4wd    4.0  2008    6    auto(l5)   4   13   19
# 81         ford     explorer 4wd    4.6  2008    8    auto(l6)   4   13   19
# 82         ford     explorer 4wd    5.0  1999    8    auto(l4)   4   13   17
# 83         ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4   14   17
# 84         ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4   14   17
# ...

# %%
df.query('manufacturer.str.startswith("f")')
# Out:
#    manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 74         ford   expedition 2wd    4.6  1999    8    auto(l4)   r   11   17
# 75         ford   expedition 2wd    5.4  1999    8    auto(l4)   r   11   17
# 76         ford   expedition 2wd    5.4  2008    8    auto(l6)   r   12   18
# 77         ford     explorer 4wd    4.0  1999    6    auto(l5)   4   14   17
# 78         ford     explorer 4wd    4.0  1999    6  manual(m5)   4   15   19
# 79         ford     explorer 4wd    4.0  1999    6    auto(l5)   4   14   17
# 80         ford     explorer 4wd    4.0  2008    6    auto(l5)   4   13   19
# 81         ford     explorer 4wd    4.6  2008    8    auto(l6)   4   13   19
# 82         ford     explorer 4wd    5.0  1999    8    auto(l4)   4   13   17
# 83         ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4   14   17
# 84         ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4   14   17
# ...

# %%
df.query('manufacturer.str.match("[af]")')
# Out:
#    manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 0          audi               a4    1.8  1999    4    auto(l5)   f   18   29
# 1          audi               a4    1.8  1999    4  manual(m5)   f   21   29
# 2          audi               a4    2.0  2008    4  manual(m6)   f   20   31
# 3          audi               a4    2.0  2008    4    auto(av)   f   21   30
# 4          audi               a4    2.8  1999    6    auto(l5)   f   16   26
# 5          audi               a4    2.8  1999    6  manual(m5)   f   18   26
# 6          audi               a4    3.1  2008    6    auto(av)   f   18   27
# 7          audi       a4 quattro    1.8  1999    4  manual(m5)   4   18   26
# 8          audi       a4 quattro    1.8  1999    4    auto(l5)   4   16   25
# 9          audi       a4 quattro    2.0  2008    4  manual(m6)   4   20   28
# 10         audi       a4 quattro    2.0  2008    4    auto(s6)   4   19   27
# ...

# %%
df[df.manufacturer.str.match('[^adf]')]
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 20     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 21     chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 22     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# ..           ...                 ...    ...   ...  ...         ...  ..  ...
# 229   volkswagen              passat    2.0  2008    4    auto(s6)   f   19
# 230   volkswagen              passat    2.0  2008    4  manual(m6)   f   21
# 231   volkswagen              passat    2.8  1999    6    auto(l5)   f   16
# 232   volkswagen              passat    2.8  1999    6  manual(m5)   f   18
# 233   volkswagen              passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 18    20  r      suv
# ...

# %%
df[df.manufacturer.str.match('[a-f]')]
# Out:
#    manufacturer    model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi       a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi       a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi       a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi       a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi       a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..          ...      ...    ...   ...  ...         ...  ..  ...  ... ..
# 94         ford  mustang    4.6  1999    8    auto(l4)   r   15   21  r
# 95         ford  mustang    4.6  1999    8  manual(m5)   r   15   22  r
# 96         ford  mustang    4.6  2008    8  manual(m5)   r   15   23  r
# 97         ford  mustang    4.6  2008    8    auto(l5)   r   15   22  r
# 98         ford  mustang    5.4  2008    8  manual(m6)   r   14   20  p
#
#          class
# 0      compact
# 1      compact
# 2      compact
# 3      compact
# 4      compact
# ...

# %%
df[df.model.str.match('a\d')]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/mn/v3yjlyh111v6w5nfq8cnqb340000gn/T/ipykernel_2303/3422847607.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df[df.model.str.match('a\d')]
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# ...

# %%
df[df.model.str.match('\d')]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/mn/v3yjlyh111v6w5nfq8cnqb340000gn/T/ipykernel_2303/3110055283.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df[df.model.str.match('\d')]
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 173       toyota  4runner 4wd    2.7  1999    4  manual(m5)   4   15   20  r
# 174       toyota  4runner 4wd    2.7  1999    4    auto(l4)   4   16   20  r
# 175       toyota  4runner 4wd    3.4  1999    6    auto(l4)   4   15   19  r
# 176       toyota  4runner 4wd    3.4  1999    6  manual(m5)   4   15   17  r
# 177       toyota  4runner 4wd    4.0  2008    6    auto(l5)   4   16   20  r
# 178       toyota  4runner 4wd    4.7  2008    8    auto(l5)   4   14   17  r
#
#     class
# 173   suv
# 174   suv
# 175   suv
# 176   suv
# 177   suv
# 178   suv

# %%
df[df.model.str.match('.i')]
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  cty  hwy fl  \
# 99         honda    civic    1.6  1999    4  manual(m5)   f   28   33  r
# 100        honda    civic    1.6  1999    4    auto(l4)   f   24   32  r
# 101        honda    civic    1.6  1999    4  manual(m5)   f   25   32  r
# 102        honda    civic    1.6  1999    4  manual(m5)   f   23   29  p
# 103        honda    civic    1.6  1999    4    auto(l4)   f   24   32  r
# 104        honda    civic    1.8  2008    4  manual(m5)   f   26   34  r
# 105        honda    civic    1.8  2008    4    auto(l5)   f   25   36  r
# 106        honda    civic    1.8  2008    4    auto(l5)   f   24   36  c
# 107        honda    civic    2.0  2008    4  manual(m6)   f   21   29  p
# 115      hyundai  tiburon    2.0  1999    4    auto(l4)   f   19   26  r
# 116      hyundai  tiburon    2.0  1999    4  manual(m5)   f   19   29  r
# 117      hyundai  tiburon    2.0  2008    4  manual(m5)   f   20   28  r
# ...
