# %% [markdown]
# # การอ่าน File จาก google sheet

# %%
import pandas as pd
print(f"pandas version :{pd.__version__}")
# Out:
# pandas version :2.2.0

# %%
from datetime import datetime

# %% [markdown]
# **สิ่งที่สำคัญคือ gid**ที่อยู่ที่ url *จะเป็นตัวกำหนดว่าเราจะเอาจาก sheet ไหน*

# %%
url =' https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/edit?hl=en&hl=en#gid=2'
url_mod = 'https://docs.google.com/spreadsheets/d/1okTb4MTllkDWlj0daHNfA8RwOPhLQkWtpQN_znJJJmk/export?gid=1&format=csv'
df = pd.read_csv(url_mod)
df
# Out:
#     Entry                                Film  \
# 0       1                           Chinatown
# 1       2                       Touch of Evil
# 2       3                             Vertigo
# 3       4                            Badlands
# 4       5                            Rashomon
# 5       6                    Double Indemnity
# 6       7                          Get Carter
# 7       8                        Pulp Fiction
# 8       9                              Hidden
# 9      10                          Goodfellas
# 10     11                    The Conversation
# 11     12                      Bonnie & Clyde
# 12     13                         The Killing
# 13     14                   French Connection
# 14     15                       The Big Sleep
# 15     16                        La Ceremonie
# 16     17                         Point Blank
# 17     18                         Hard Boiled
# 18     19                    Long Good Friday
# ...

# %% [markdown]
# จะเห็นว่าเปลี่ยนตรง /edit ให้เป็นเป็น export?gid=2&format=csv
# ***จาก edit?hl=en&hl=en#gid=2
# เป็น export?gid=2&format=csv***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Entry                   25 non-null     int64
#  1   Cat                     25 non-null     object
#  2   Film                    25 non-null     object
#  3   Director                25 non-null     object
#  4   Leading actors          25 non-null     object
#  5   Year of cinema release  25 non-null     int64
#  6   Oscars won              3 non-null      float64
#  7   IMDB link               25 non-null     object
#  8   Guardian film page      25 non-null     object
#  9   Country                 25 non-null     object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.1+ KB
