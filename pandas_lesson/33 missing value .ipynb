# %%
import pandas as pd

# %%
df = pd.read_csv('msleep.csv')
df
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
# ...

# %%
df.dropna()
# Out:
#                               name         genus     vore            order  \
# 3       Greater short-tailed shrew       Blarina     omni     Soricomorpha
# 4                              Cow           Bos    herbi     Artiodactyla
# 8                              Dog         Canis    carni        Carnivora
# 11                      Guinea pig         Cavis    herbi         Rodentia
# 13                      Chinchilla    Chinchilla    herbi         Rodentia
# 16       Lesser short-tailed shrew     Cryptotis     omni     Soricomorpha
# 17            Long-nosed armadillo       Dasypus    carni        Cingulata
# 19          North American Opossum     Didelphis     omni  Didelphimorphia
# 21                   Big brown bat     Eptesicus  insecti       Chiroptera
# 22                           Horse         Equus    herbi   Perissodactyla
# 24               European hedgehog     Erinaceus     omni   Erinaceomorpha
# ...

# %%
df1 = df.dropna()
df1
# Out:
#                               name         genus     vore            order  \
# 3       Greater short-tailed shrew       Blarina     omni     Soricomorpha
# 4                              Cow           Bos    herbi     Artiodactyla
# 8                              Dog         Canis    carni        Carnivora
# 11                      Guinea pig         Cavis    herbi         Rodentia
# 13                      Chinchilla    Chinchilla    herbi         Rodentia
# 16       Lesser short-tailed shrew     Cryptotis     omni     Soricomorpha
# 17            Long-nosed armadillo       Dasypus    carni        Cingulata
# 19          North American Opossum     Didelphis     omni  Didelphimorphia
# 21                   Big brown bat     Eptesicus  insecti       Chiroptera
# 22                           Horse         Equus    herbi   Perissodactyla
# 24               European hedgehog     Erinaceus     omni   Erinaceomorpha
# ...

# %%
print(f"df = {df.shape } df1 = {df1.shape}")
# Out:
# df = (83, 11) df1 = (20, 11)

# %%
df2 = df1.dropna(axis=1)
df2
# Out:
#                               name         genus     vore            order  \
# 3       Greater short-tailed shrew       Blarina     omni     Soricomorpha
# 4                              Cow           Bos    herbi     Artiodactyla
# 8                              Dog         Canis    carni        Carnivora
# 11                      Guinea pig         Cavis    herbi         Rodentia
# 13                      Chinchilla    Chinchilla    herbi         Rodentia
# 16       Lesser short-tailed shrew     Cryptotis     omni     Soricomorpha
# 17            Long-nosed armadillo       Dasypus    carni        Cingulata
# 19          North American Opossum     Didelphis     omni  Didelphimorphia
# 21                   Big brown bat     Eptesicus  insecti       Chiroptera
# 22                           Horse         Equus    herbi   Perissodactyla
# 24               European hedgehog     Erinaceus     omni   Erinaceomorpha
# ...

# %%
df3 = pd.read_csv('qnaire_missing_values.csv')

# %%
df3
# Out:
#     obs gender   age  eq1  eq2  eq3  eq4  eq5  eq6  eq7  eq8  eq9  eq10
# 0     1      M  37.0  1.0  5.0  2.0  1.0  1.0  5.0  3.0  5.0  4.0   2.0
# 1     2      F   NaN  NaN  1.0  4.0  1.0  1.0  2.0  3.0  5.0  4.0   2.0
# 2     3    NaN  29.0  2.0  5.0  NaN  2.0  5.0  NaN  3.0  3.0  1.0   1.0
# 3     4      M  25.0  5.0  2.0  4.0  NaN  4.0  4.0  2.0  4.0  4.0   1.0
# 4     5      F  19.0  1.0  5.0  4.0  4.0  5.0  2.0  3.0  2.0  2.0   1.0
# 5     6    NaN  26.0  4.0  5.0  NaN  2.0  4.0  2.0  NaN  NaN  NaN   3.0
# 6     7      F   NaN  3.0  2.0  3.0  5.0  1.0  1.0  2.0  3.0  4.0   4.0
# 7     8      F  40.0  5.0  2.0  3.0  1.0  2.0  NaN  2.0  1.0  3.0   NaN
# 8     9      M  39.0  5.0  NaN  NaN  2.0  2.0  2.0  3.0  1.0  2.0   5.0
# 9    10    NaN   NaN  5.0  4.0  1.0  5.0  4.0  5.0  5.0  3.0  4.0   1.0
# 10   11      F  31.0  2.0  NaN  NaN  NaN  1.0  NaN  3.0  1.0  1.0   5.0
# 11   12      F  29.0  3.0  4.0  2.0  2.0  2.0  2.0  1.0  5.0  3.0   4.0
# ...

# %%
df3.dropna()
# Out:
#     obs gender   age  eq1  eq2  eq3  eq4  eq5  eq6  eq7  eq8  eq9  eq10
# 0     1      M  37.0  1.0  5.0  2.0  1.0  1.0  5.0  3.0  5.0  4.0   2.0
# 4     5      F  19.0  1.0  5.0  4.0  4.0  5.0  2.0  3.0  2.0  2.0   1.0
# 11   12      F  29.0  3.0  4.0  2.0  2.0  2.0  2.0  1.0  5.0  3.0   4.0

# %%
df3.dropna(thresh=10)
# Out:
#     obs gender   age  eq1  eq2  eq3  eq4  eq5  eq6  eq7  eq8  eq9  eq10
# 0     1      M  37.0  1.0  5.0  2.0  1.0  1.0  5.0  3.0  5.0  4.0   2.0
# 1     2      F   NaN  NaN  1.0  4.0  1.0  1.0  2.0  3.0  5.0  4.0   2.0
# 2     3    NaN  29.0  2.0  5.0  NaN  2.0  5.0  NaN  3.0  3.0  1.0   1.0
# 3     4      M  25.0  5.0  2.0  4.0  NaN  4.0  4.0  2.0  4.0  4.0   1.0
# 4     5      F  19.0  1.0  5.0  4.0  4.0  5.0  2.0  3.0  2.0  2.0   1.0
# 6     7      F   NaN  3.0  2.0  3.0  5.0  1.0  1.0  2.0  3.0  4.0   4.0
# 7     8      F  40.0  5.0  2.0  3.0  1.0  2.0  NaN  2.0  1.0  3.0   NaN
# 8     9      M  39.0  5.0  NaN  NaN  2.0  2.0  2.0  3.0  1.0  2.0   5.0
# 9    10    NaN   NaN  5.0  4.0  1.0  5.0  4.0  5.0  5.0  3.0  4.0   1.0
# 11   12      F  29.0  3.0  4.0  2.0  2.0  2.0  2.0  1.0  5.0  3.0   4.0
# 12   13      F   NaN  4.0  4.0  4.0  2.0  2.0  3.0  4.0  4.0  4.0   2.0
# 14   15      F  34.0  4.0  5.0  1.0  2.0  NaN  3.0  NaN  1.0  2.0   4.0

# %%
df3.dropna(thresh = 8, subset=['eq1', 'eq2', 'eq3', 'eq4', 'eq5', 'eq6', 'eq7',
       'eq8', 'eq9', 'eq10'])
# Out:
#     obs gender   age  eq1  eq2  eq3  eq4  eq5  eq6  eq7  eq8  eq9  eq10
# 0     1      M  37.0  1.0  5.0  2.0  1.0  1.0  5.0  3.0  5.0  4.0   2.0
# 1     2      F   NaN  NaN  1.0  4.0  1.0  1.0  2.0  3.0  5.0  4.0   2.0
# 2     3    NaN  29.0  2.0  5.0  NaN  2.0  5.0  NaN  3.0  3.0  1.0   1.0
# 3     4      M  25.0  5.0  2.0  4.0  NaN  4.0  4.0  2.0  4.0  4.0   1.0
# 4     5      F  19.0  1.0  5.0  4.0  4.0  5.0  2.0  3.0  2.0  2.0   1.0
# 6     7      F   NaN  3.0  2.0  3.0  5.0  1.0  1.0  2.0  3.0  4.0   4.0
# 7     8      F  40.0  5.0  2.0  3.0  1.0  2.0  NaN  2.0  1.0  3.0   NaN
# 8     9      M  39.0  5.0  NaN  NaN  2.0  2.0  2.0  3.0  1.0  2.0   5.0
# 9    10    NaN   NaN  5.0  4.0  1.0  5.0  4.0  5.0  5.0  3.0  4.0   1.0
# 11   12      F  29.0  3.0  4.0  2.0  2.0  2.0  2.0  1.0  5.0  3.0   4.0
# 12   13      F   NaN  4.0  4.0  4.0  2.0  2.0  3.0  4.0  4.0  4.0   2.0
# 14   15      F  34.0  4.0  5.0  1.0  2.0  NaN  3.0  NaN  1.0  2.0   4.0

# %%
df3.columns.str.contains('eq')
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
df3.columns[df3.columns.str.contains('eq')]
# Out:
# Index(['eq1', 'eq2', 'eq3', 'eq4', 'eq5', 'eq6', 'eq7', 'eq8', 'eq9', 'eq10'], dtype='object')

# %%
df3.dropna(subset=df3.columns[df3.columns.str.contains('eq')])
# Out:
#     obs gender   age  eq1  eq2  eq3  eq4  eq5  eq6  eq7  eq8  eq9  eq10
# 0     1      M  37.0  1.0  5.0  2.0  1.0  1.0  5.0  3.0  5.0  4.0   2.0
# 4     5      F  19.0  1.0  5.0  4.0  4.0  5.0  2.0  3.0  2.0  2.0   1.0
# 6     7      F   NaN  3.0  2.0  3.0  5.0  1.0  1.0  2.0  3.0  4.0   4.0
# 9    10    NaN   NaN  5.0  4.0  1.0  5.0  4.0  5.0  5.0  3.0  4.0   1.0
# 11   12      F  29.0  3.0  4.0  2.0  2.0  2.0  2.0  1.0  5.0  3.0   4.0
# 12   13      F   NaN  4.0  4.0  4.0  2.0  2.0  3.0  4.0  4.0  4.0   2.0
